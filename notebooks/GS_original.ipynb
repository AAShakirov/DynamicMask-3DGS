# %% [markdown]
# # Using original 3DGS repository

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# diff-gaussian-rasterization
# %cd gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q .

# simple-knn (из рабочего репозитория)
# %cd /content
# !git clone https://gitlab.inria.fr/bkerbl/simple-knn.git
# %cd simple-knn
# !pip install -q .
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 5.60 MiB/s, done.
# Resolving deltas: 100% (344/344), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# %cd /content/gaussian-splatting

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train
# Out:
# /content/gaussian-splatting
# --2025-12-08 11:57:20--  https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# Resolving huggingface.co (huggingface.co)... 3.168.132.126, 3.168.132.40, 3.168.132.38, ...
# Connecting to huggingface.co (huggingface.co)|3.168.132.126|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python render.py -m '/content/gaussian-splatting/output/09d04532-3/'
# Out:
# Looking for config file in /content/gaussian-splatting/output/09d04532-3/cfg_args
# Config file found: /content/gaussian-splatting/output/09d04532-3/cfg_args
# Rendering /content/gaussian-splatting/output/09d04532-3/
# Loading trained model at iteration 30000 [08/12 12:48:59]
# Reading camera 301/301 [08/12 12:49:01]
# Loading Training Cameras [08/12 12:49:01]
# Loading Test Cameras [08/12 12:49:05]
# Rendering progress: 100% 301/301 [02:15<00:00,  2.23it/s]
# Rendering progress: 0it [00:00, ?it/s]

# %%
# !zip -r GS-original-tandt_db.zip /content/gaussian-splatting/output
# Out:
#   adding: content/gaussian-splatting/output/ (stored 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/ (stored 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ (stored 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/ (stored 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/ (stored 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/00225.png (deflated 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/00171.png (deflated 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/00300.png (deflated 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/00276.png (deflated 0%)
#   adding: content/gaussian-splatting/output/09d04532-3/train/ours_30000/renders/00018.png (deflated 0%)
# ...
